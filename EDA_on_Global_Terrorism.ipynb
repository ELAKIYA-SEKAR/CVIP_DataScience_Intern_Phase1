# %% [markdown]
# **Import the necessary libraries required for Exploratory Data Analysis(EDA)**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Read the Global Terrorism dataset using the read_csv**

# %%
terrorism = pd.read_csv("/content/globalterrorismdb_0718dist.csv", encoding='ISO-8859-1', error_bad_lines=False)

# %% [markdown]
# **Importing warning and set it to ignore to ignore the warnings**

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Describing the statistical view of the data**

# %%
terrorism.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  2.435900e+04  24359.000000  24359.000000  24359.000000  24359.000000
# mean   1.981010e+11   1980.947453      6.135474     15.098731      0.019911
# std    7.885237e+08      7.890739      3.339157      8.951988      0.139696
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.978031e+11   1978.000000      3.000000      7.000000      0.000000
# 50%    1.980103e+11   1980.000000      6.000000     15.000000      0.000000
# 75%    1.983031e+11   1983.000000      9.000000     23.000000      0.000000
# max    2.015042e+11   2015.000000     12.000000     31.000000      1.000000
#
#             country        region         crit1         crit2         crit3  \
# count  24359.000000  24359.000000  24358.000000  24358.000000  24358.000000
# mean     167.996084      5.390041      0.990065      0.991050      0.857706
# std      157.971485      3.325841      0.116327      0.094181      0.354608
# min        4.000000      1.000000     -9.000000      0.000000     -9.000000
# 25%       61.000000      2.000000      1.000000      1.000000      1.000000
# 50%      110.000000      5.000000      1.000000      1.000000      1.000000
# 75%      185.000000      8.000000      1.000000      1.000000      1.000000
# max     1004.000000     12.000000      1.000000      1.000000      1.000000
#
#        ...     ransomamt   ransomamtus    ransompaid  ransompaidus  \
# count  ...  4.760000e+02      9.000000  1.040000e+02           9.0
# mean   ...  3.590488e+06   2222.222222  1.154369e+06           0.0
# std    ...  4.623719e+07   6666.666667  4.485766e+06           0.0
# min    ... -9.900000e+01      0.000000 -9.900000e+01           0.0
# 25%    ...  0.000000e+00      0.000000  0.000000e+00           0.0
# 50%    ...  0.000000e+00      0.000000  4.000000e+04           0.0
# 75%    ...  4.097500e+05      0.000000  5.025000e+05           0.0
# max    ...  1.000000e+09  20000.000000  4.100000e+07           0.0
#
#        hostkidoutcome   nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count      841.000000  668.000000  24356.000000  24356.000000  24356.000000
# mean         3.158145    3.848802     -3.474462     -3.424372      0.222245
# std          1.563713   42.664932      4.481047      4.534363      0.636919
# min          1.000000  -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000    1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000    1.000000      0.000000      0.000000      0.000000
# 75%          4.000000    2.000000      0.000000      0.000000      0.000000
# max          7.000000  390.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  24356.000000
# mean      -2.558056
# std        4.459167
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 69 columns]

# %% [markdown]
# **To find the shape of the dataset**

# %%
terrorism.shape
# Out:
# (24359, 135)

# %% [markdown]
# **Analysing the data types of the columns**

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24359 entries, 0 to 24358
# Columns: 135 entries, eventid to related
# dtypes: float64(63), int64(6), object(66)
# memory usage: 25.1+ MB

# %% [markdown]
# **Displaying the columns**

# %%
terrorism.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# **Viewing the total number of columns**

# %%
terrorism.columns.nunique()
# Out:
# 135

# %% [markdown]
# **Only taking the columns which are related for the analysis of our dataset**

# %%
terrorism = terrorism[['iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
                       'provstate', 'city', 'attacktype1_txt', 'targtype1_txt',
                       'targsubtype1_txt', 'gname', 'weaptype1_txt']]

# %%
terrorism.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'provstate',
#        'city', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt', 'gname',
#        'weaptype1_txt'],
#       dtype='object')

# %% [markdown]
# **Renaming the columns**

# %%
terrorism = terrorism.rename(columns={'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country',
                       'region_txt':'Region','provstate':'Province_State', 'city':'City', 'attacktype1_txt':'Attacktype', 'targtype1_txt':'Targettype',
                       'targsubtype1_txt':'Target', 'gname':'Gang_name', 'weaptype1_txt':'Weapon'})

# %%
terrorism
# Out:
#        Year  Month  Day             Country                       Region  \
# 0      1970      7    2  Dominican Republic  Central America & Caribbean
# 1      1970      0    0              Mexico                North America
# 2      1970      1    0         Philippines               Southeast Asia
# 3      1970      1    0              Greece               Western Europe
# 4      1970      1    0               Japan                    East Asia
# ...     ...    ...  ...                 ...                          ...
# 24354  1984      9   26               Chile                South America
# 24355  1984      9   26               Spain               Western Europe
# 24356  1984      9   26              Mexico                North America
# 24357  1984      9   26         El Salvador  Central America & Caribbean
# 24358  1984      9   26         El Salvador  Central America & Caribbean
#
#               Province_State                 City  \
# 0                        NaN        Santo Domingo
# 1                    Federal          Mexico city
# 2                     Tarlac              Unknown
# 3                     Attica               Athens
# 4                    Fukouka              Fukouka
# ...                      ...                  ...
# 24354  Santiago Metropolitan             Santiago
# 24355         Basque Country              Vergara
# 24356                 Puebla  San Jose Miahuatlan
# 24357               Usulutan           El Triunfo
# 24358               La Union           Las Marias
#
#                            Attacktype                   Targettype  \
# 0                       Assassination  Private Citizens & Property
# 1         Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                       Assassination          Journalists & Media
# 3                   Bombing/Explosion      Government (Diplomatic)
# 4      Facility/Infrastructure Attack      Government (Diplomatic)
# ...                               ...                          ...
# 24354               Bombing/Explosion                     Business
# 24355                   Armed Assault  Private Citizens & Property
# 24356                   Assassination         Government (General)
# 24357                   Armed Assault  Private Citizens & Property
# 24358                             NaN                          NaN
#
#                                                   Target  \
# 0                                         Named Civilian
# 1      Diplomatic Personnel (outside of embassy, cons...
# 2                        Radio Journalist/Staff/Facility
# 3                                      Embassy/Consulate
# 4                                      Embassy/Consulate
# ...                                                  ...
# 24354                              Retail/Grocery/Bakery
# 24355                            Vehicles/Transportation
# 24356  Politician or Political Party Movement/Meeting...
# 24357                          House/Apartment/Residence
# 24358                                                NaN
#
#                                               Gang_name      Weapon
# 0                                                MANO-D     Unknown
# 1                    23rd of September Communist League     Unknown
# 2                                               Unknown     Unknown
# 3                                               Unknown  Explosives
# 4                                               Unknown  Incendiary
# ...                                                 ...         ...
# 24354                                           Unknown  Explosives
# 24355                                           Unknown    Firearms
# 24356                                           Unknown    Firearms
# 24357  Farabundo Marti National Liberation Front (FMLN)    Firearms
# 24358                                               NaN         NaN
#
# [24359 rows x 12 columns]

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24359 entries, 0 to 24358
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            24359 non-null  int64
#  1   Month           24359 non-null  int64
#  2   Day             24359 non-null  int64
#  3   Country         24359 non-null  object
#  4   Region          24359 non-null  object
#  5   Province_State  24256 non-null  object
#  6   City            24358 non-null  object
#  7   Attacktype      24357 non-null  object
#  8   Targettype      24357 non-null  object
#  9   Target          23037 non-null  object
#  10  Gang_name       24356 non-null  object
#  11  Weapon          24356 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 2.2+ MB

# %%
terrorism.isnull().sum()
# Out:
# Year                 0
# Month                0
# Day                  0
# Country              0
# Region               0
# Province_State     103
# City                 1
# Attacktype           2
# Targettype           2
# Target            1322
# Gang_name            3
# Weapon               3
# dtype: int64

# %%
terrorism['Targettype'] = terrorism['Targettype'].fillna('Unknown')

# %%
terrorism['Target'] = terrorism['Target'].fillna('Unknown')

# %%
terrorism['Province_State'] = terrorism['Province_State'].fillna('Unknown')

# %%
terrorism['City'] = terrorism['City'].fillna('Unknown')

# %%
terrorism.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# Region            0
# Province_State    0
# City              0
# Attacktype        2
# Targettype        0
# Target            0
# Gang_name         3
# Weapon            3
# dtype: int64

# %% [markdown]
# **Statistical Description of the dataset**

# %%
terrorism.describe()
# Out:
#                Year         Month           Day
# count  24359.000000  24359.000000  24359.000000
# mean    1980.947453      6.135474     15.098731
# std        7.890739      3.339157      8.951988
# min     1970.000000      0.000000      0.000000
# 25%     1978.000000      3.000000      7.000000
# 50%     1980.000000      6.000000     15.000000
# 75%     1983.000000      9.000000     23.000000
# max     2015.000000     12.000000     31.000000

# %% [markdown]
# **Top 5 afftected Regions**

# %%
terrorism['Region'].value_counts().head(5)
# Out:
# Western Europe                 7083
# Central America & Caribbean    5527
# South America                  4483
# Middle East & North Africa     3125
# North America                  1935
# Name: Region, dtype: int64

# %% [markdown]
# **Top 5 afftected Country**

# %%
terrorism['Country'].value_counts().head(5)
# Out:
# El Salvador       2928
# United Kingdom    2337
# United States     1787
# Spain             1578
# Peru              1575
# Name: Country, dtype: int64

# %% [markdown]
# **Top 5 affected State**

# %%
terrorism['Province_State'].value_counts().head(5)
# Out:
# Northern Ireland    2106
# San Salvador        1200
# Unknown             1110
# Basque Country       581
# Guatemala            581
# Name: Province_State, dtype: int64

# %% [markdown]
# **Top 5 affected City**

# %%
terrorism['City'].value_counts().head(5)
# Out:
# Unknown         1420
# Belfast         1044
# San Salvador     982
# Santiago         478
# Rome             468
# Name: City, dtype: int64

# %% [markdown]
# **Top 5 attacking modes**

# %%
terrorism['Targettype'].value_counts().head(10)
# Out:
# Business                       4665
# Private Citizens & Property    4068
# Military                       3771
# Government (General)           2788
# Police                         2481
# Government (Diplomatic)        1198
# Utilities                      1028
# Transportation                  985
# Journalists & Media             650
# Educational Institution         584
# Name: Targettype, dtype: int64

# %% [markdown]
# **Top 5 attacking Gang Names**

# %%
terrorism['Gang_name'].value_counts().head(10)
# Out:
# Unknown                                             8115
# Irish Republican Army (IRA)                         1524
# Shining Path (SL)                                   1246
# Farabundo Marti National Liberation Front (FMLN)    1108
# Basque Fatherland and Freedom (ETA)                  907
# Palestinians                                         469
# Revolutionary Armed Forces of Colombia (FARC)        404
# Nicaraguan Democratic Force (FDN)                    388
# M-19 (Movement of April 19)                          321
# Movement of the Revolutionary Left (MIR) (Chile)     240
# Name: Gang_name, dtype: int64

# %% [markdown]
# **Top 5 weapon types**

# %%
terrorism['Weapon'].value_counts().head(10)
# Out:
# Explosives                                                                     10734
# Firearms                                                                        8549
# Unknown                                                                         2705
# Incendiary                                                                      2123
# Melee                                                                            164
# Chemical                                                                          38
# Sabotage Equipment                                                                17
# Other                                                                              8
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)        6
# Biological                                                                         6
# Name: Weapon, dtype: int64

# %% [markdown]
# **Most Attacks Happened and its count**

# %%
print("Country with the most attacks and count:",terrorism['Country'].value_counts().head(1))
print("City with the most attacks and count:",terrorism['City'].value_counts().index[1])
print("Region with the most attacks and count:",terrorism['Region'].value_counts().head(1))
print("State with the most attacks and count:",terrorism['Province_State'].value_counts().head(1))
print("City with the most attacks and count:",terrorism['City'].value_counts().head(1))
print("Year with the most attacks and count:",terrorism['Year'].value_counts().head(1))
print("Month with the most attacks and count:",terrorism['Month'].value_counts().head(1))
print("Day with the most attacks and count:",terrorism['Day'].value_counts().head(1))
print("Gang with the most attacksand count:",terrorism['Gang_name'].value_counts().head(1))
print("Most attack types and count:",terrorism['Weapon'].value_counts().head(1))
# Out:
# Country with the most attacks and count: El Salvador    2928
# Name: Country, dtype: int64
# City with the most attacks and count: Belfast
# Region with the most attacks and count: Western Europe    7083
# Name: Region, dtype: int64
# State with the most attacks and count: Northern Ireland    2106
# Name: Province_State, dtype: int64
# City with the most attacks and count: Unknown    1420
# Name: City, dtype: int64
# Year with the most attacks and count: 1983    2870
# Name: Year, dtype: int64
# Month with the most attacks and count: 4    2813
# Name: Month, dtype: int64
# Day with the most attacks and count: 1    969
# Name: Day, dtype: int64
# Gang with the most attacksand count: Unknown    8115
# Name: Gang_name, dtype: int64
# Most attack types and count: Explosives    10734
# Name: Weapon, dtype: int64

# %% [markdown]
# **Visualization**

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24359 entries, 0 to 24358
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            24359 non-null  int64
#  1   Month           24359 non-null  int64
#  2   Day             24359 non-null  int64
#  3   Country         24359 non-null  object
#  4   Region          24359 non-null  object
#  5   Province_State  24359 non-null  object
#  6   City            24359 non-null  object
#  7   Attacktype      24357 non-null  object
#  8   Targettype      24359 non-null  object
#  9   Target          24359 non-null  object
#  10  Gang_name       24356 non-null  object
#  11  Weapon          24356 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# **Attacks by day and month**

# %%
plt.figure(figsize=(20, 15))

titles = ['Attacks by Day', 'Attacks by Month']

columns = ['Day', 'Month']

for i, col in enumerate(columns):
    plt.subplot(2, 1, i + 1)
    plt.title(titles[i])
    sns.countplot(x=terrorism[col])

plt.tight_layout()

plt.show()

# %% [markdown]
# **Attacks by Region and Country**

# %%
plt.figure(figsize=(10, 15))

# Titles for the plots
titles = ['Attacks by Region', 'Attacks by Country']

# Columns to be used for each plot
columns = ['Region', 'Country']

for i, col in enumerate(columns):
    # Create a subplot for each plot
    plt.subplot(2, 1, i + 1)
    plt.rcParams.update({'font.size':8})
    plt.xticks(rotation=90)
    plt.title(titles[i])
    sns.countplot(x=terrorism[col])

# Adjust spacing between subplots
plt.tight_layout()

# Show the combined figure
plt.show()

# %% [markdown]
# **Based on Attack type**

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=45)
plt.title('Based on Attack type')
sns.countplot(x=terrorism['Attacktype'])
# Out:
# <Axes: title={'center': 'Based on Attack type'}, xlabel='Attacktype', ylabel='count'>

# %% [markdown]
# **Based on Target type**

# %%
plt.figure(figsize=(20,15))
plt.xticks(rotation=45)
plt.title('Based on Target type')
sns.countplot(x=terrorism['Targettype'])
# Out:
# <Axes: title={'center': 'Based on Target type'}, xlabel='Targettype', ylabel='count'>

# %% [markdown]
# **Attacks by year**

# %%
plt.figure(figsize=(20,15))
plt.xticks(rotation=360)
plt.title('Attacks by Year')
sns.countplot(x=terrorism['Year'])
# Out:
# <Axes: title={'center': 'Attacks by Year'}, xlabel='Year', ylabel='count'>

# %% [markdown]
# **Terrorist Activities by Region in each Year**

# %%
pd.crosstab(terrorism.Year, terrorism.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()
